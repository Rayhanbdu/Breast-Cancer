# %%
import json
import math
import os
import gc
import itertools
from functools import partial
from collections import Counter

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

from PIL import Image
from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras import layers, backend as K
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Dropout, Flatten, Dense, GlobalAveragePooling2D, Average,
    Input, Concatenate, GlobalMaxPooling2D, BatchNormalization
)
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
from sklearn import metrics

# %matplotlib inline
# Out:
# 2026-05-16 03:58:44.841966: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778903925.080190      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778903925.143838      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778903925.696281      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778903925.696324      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778903925.696326      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778903925.696329      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf

# Disable XLA
tf.config.optimizer.set_jit(False)

# %%
def Dataset_loader_recursive(DIR, RESIZE):
    IMG = []
    
    for root, _, files in os.walk(DIR):
        for file in files:
            PATH = os.path.join(root, file)
            _, ftype = os.path.splitext(PATH)
            
            if ftype.lower() in [".jpg", ".jpeg", ".png"]:
                try:
                    img = np.asarray(Image.open(PATH).convert("RGB"))
                    img = cv2.resize(img, (RESIZE, RESIZE))
                    IMG.append(img)
                except:
                    continue
    
    return np.array(IMG)
DIR = "/kaggle/input/datasets/tueoban/aisslab-breast-cancer-sub-datasets/AISSLab Sub-datasets/Augmented Sub-datasets/AISSLab-v5/"

benign_bi_rads_2 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 2"), RESIZE=224)
benign_bi_rads_3 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 3"), RESIZE=224)

malignant_bi_rads_4 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 4"), RESIZE=224)
malignant_bi_rads_5 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 5"), RESIZE=224)

#normal = Dataset_loader_recursive(os.path.join(DIR, "Normal/JPG/"), RESIZE=224)

# %%
print("Total images loaded:", len(benign_bi_rads_2))
print("Shape:", benign_bi_rads_2.shape)

print("Total images loaded:", len(benign_bi_rads_3))
print("Shape:", benign_bi_rads_3.shape)

print("Total images loaded:", len(malignant_bi_rads_4))
print("Shape:", malignant_bi_rads_4.shape)

print("Total images loaded:", len(malignant_bi_rads_5))
print("Shape:", malignant_bi_rads_5.shape)
# Out:
# Total images loaded: 72
# Shape: (72, 224, 224, 3)
# Total images loaded: 192
# Shape: (192, 224, 224, 3)
# Total images loaded: 224
# Shape: (224, 224, 224, 3)
# Total images loaded: 176
# Shape: (176, 224, 224, 3)

# %%
#normal_label = np.full(len(normal),0)
benign_bi_rads_2_label = np.full(len(benign_bi_rads_2), 0)
benign_bi_rads_3_label = np.full(len(benign_bi_rads_3),1)
malignant_bi_rads_4_label = np.full(len(malignant_bi_rads_4),2)
malignant_bi_rads_5_label = np.full(len(malignant_bi_rads_5),3)

# %%
X = np.concatenate((benign_bi_rads_2, benign_bi_rads_3, malignant_bi_rads_4, malignant_bi_rads_5), axis = 0)
Y = np.concatenate((benign_bi_rads_2_label, benign_bi_rads_3_label, malignant_bi_rads_4_label, malignant_bi_rads_5_label), axis = 0)

# Shuffle train data
s = np.arange(X.shape[0])
np.random.shuffle(s)
X = X[s]
Y = Y[s]

# DENSENET PREPROCESSING
X = preprocess_input(
    X.astype("float32")
)
x_train, x_test, y_train, y_test = train_test_split(
    X, Y, 
    test_size=0.2, 
    random_state=11,
    stratify=Y
)

# %%
from imblearn.over_sampling import RandomOverSampler
from tensorflow.keras.utils import to_categorical
from collections import Counter
import numpy as np

# -----------------------------
# Convert one-hot -> labels if needed
# -----------------------------
if len(y_train.shape) > 1:
    y_train_labels = np.argmax(y_train, axis=1)
else:
    y_train_labels = y_train

# -----------------------------
# Check original distribution
# -----------------------------
print("Original class distribution:")
print(Counter(y_train_labels))

# -----------------------------
# Flatten image data temporarily
# -----------------------------
nsamples, h, w, c = x_train.shape

x_train_flat = x_train.reshape(
    (nsamples, h * w * c)
)

target = 1200
# -----------------------------
# Target: 100 samples per class
# -----------------------------
sampling_strategy = {
    0: target,
    1: target,
    2: target,
    3: target
}

# -----------------------------
# Apply Oversampling
# -----------------------------
ros = RandomOverSampler(
    sampling_strategy=sampling_strategy,
    random_state=42
)

x_train, y_train = ros.fit_resample(
    x_train_flat,
    y_train_labels
)

# -----------------------------
# Restore image shape
# -----------------------------
x_train = x_train.reshape(
    (-1, h, w, c)
)

# -----------------------------
# One-hot Encode Labels
# -----------------------------
y_train = to_categorical(
    y_train,
    num_classes=4
)

# -----------------------------
# Validation labels
# -----------------------------
if len(y_test.shape) == 1:
    y_test = to_categorical(y_test, num_classes=4)

# -----------------------------
# Final Distribution
# -----------------------------
print("\nBalanced class distribution:")
print(Counter(np.argmax(y_train, axis=1)))
# Out:
# Original class distribution:
# Counter({np.int64(2): 179, np.int64(1): 153, np.int64(3): 141, np.int64(0): 58})
#
# Balanced class distribution:
# Counter({np.int64(3): 1200, np.int64(0): 1200, np.int64(1): 1200, np.int64(2): 1200})

# %%
x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, 
    test_size=0.2, 
    random_state=11,
    stratify=np.argmax(y_train, axis=1)
)
print("\nFinal Shapes:")
print("x_train:", x_train.shape)
print("y_train:", y_train.shape)
print("x_val:", x_val.shape)
print("y_val:", y_val.shape)
print("x_test:", x_test.shape)
print("y_test:", y_test.shape)
# Out:
# Final Shapes:
# x_train: (3840, 224, 224, 3)
# y_train: (3840, 4)
# x_val: (960, 224, 224, 3)
# y_val: (960, 4)
# x_test: (133, 224, 224, 3)
# y_test: (133, 4)

# %%
BATCH_SIZE = 32

# Using original generator
train_generator = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=False
)

# %%
IMAGE_SIZE = 224

input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)
inputs = Input(shape=input_shape)

# PRETRAINED VGG16
vgg = VGG16(
    weights='imagenet',
    include_top=False,
    input_tensor=inputs
)
# Out:
# I0000 00:00:1778904015.751706      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1778904015.757764      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# FREEZE
for layer in vgg.layers:
    layer.trainable = False

# %%
# CLASSIFIER HEAD
x = vgg.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(256,activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.4)(x)
outputs = Dense(4,activation='softmax')(x)

# FINAL MODEL
model = Model(inputs,outputs)

# %%
# COMPILE
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,850,116 (56.65 MB)
#  Trainable params: 133,892 (523.02 KB)
#  Non-trainable params: 14,716,224 (56.14 MB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

filepath = "/kaggle/working/best_AISSlab.keras"

checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',   # also fix this (see below 👇)
    verbose=1,
    save_best_only=True,
    mode='max'
)

# Early stopping
early_stopping = EarlyStopping(
    monitor='val_accuracy',  
    patience=8,             
    verbose=1,
    mode='max',
    restore_best_weights=True
)

# LR 
learn_control = ReduceLROnPlateau(
    monitor='val_loss',
    patience=3,
    factor=0.3,
    min_lr=1e-6,
    verbose=1
)

# %%
history = model.fit(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] // BATCH_SIZE,
    epochs=30,
    validation_data=(x_val, y_val),
    callbacks=[checkpoint, early_stopping, learn_control]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778904020.670036      70 service.cc:152] XLA service 0x7a21d00105e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778904020.670082      70 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1778904020.670087      70 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1778904021.274898      70 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   1/120 ━━━━━━━━━━━━━━━━━━━━ 32:09 16s/step - accuracy: 0.2812 - loss: 2.1641
# I0000 00:00:1778904034.589206      70 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.2774 - loss: 2.1492
# Epoch 1: val_accuracy improved from -inf to 0.38958, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 62s 388ms/step - accuracy: 0.2776 - loss: 2.1484 - val_accuracy: 0.3896 - val_loss: 1.3916 - learning_rate: 1.0000e-04
# Epoch 2/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.3318 - loss: 1.8788
# Epoch 2: val_accuracy improved from 0.38958 to 0.45729, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 44s 368ms/step - accuracy: 0.3320 - loss: 1.8781 - val_accuracy: 0.4573 - val_loss: 1.2182 - learning_rate: 1.0000e-04
# Epoch 3/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.3836 - loss: 1.6354
# Epoch 3: val_accuracy improved from 0.45729 to 0.47604, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 374ms/step - accuracy: 0.3836 - loss: 1.6353 - val_accuracy: 0.4760 - val_loss: 1.1418 - learning_rate: 1.0000e-04
# Epoch 4/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.4368 - loss: 1.5008
# Epoch 4: val_accuracy improved from 0.47604 to 0.50833, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 381ms/step - accuracy: 0.4367 - loss: 1.5010 - val_accuracy: 0.5083 - val_loss: 1.0651 - learning_rate: 1.0000e-04
# Epoch 5/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.4503 - loss: 1.4611
# Epoch 5: val_accuracy improved from 0.50833 to 0.56771, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 381ms/step - accuracy: 0.4502 - loss: 1.4611 - val_accuracy: 0.5677 - val_loss: 0.9694 - learning_rate: 1.0000e-04
# Epoch 6/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.4795 - loss: 1.3868
# Epoch 6: val_accuracy improved from 0.56771 to 0.58854, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 377ms/step - accuracy: 0.4796 - loss: 1.3867 - val_accuracy: 0.5885 - val_loss: 0.9121 - learning_rate: 1.0000e-04
# Epoch 7/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.4747 - loss: 1.3410
# Epoch 7: val_accuracy improved from 0.58854 to 0.63021, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 378ms/step - accuracy: 0.4747 - loss: 1.3410 - val_accuracy: 0.6302 - val_loss: 0.8567 - learning_rate: 1.0000e-04
# Epoch 8/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.4790 - loss: 1.3364
# Epoch 8: val_accuracy improved from 0.63021 to 0.65521, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 376ms/step - accuracy: 0.4791 - loss: 1.3362 - val_accuracy: 0.6552 - val_loss: 0.8261 - learning_rate: 1.0000e-04
# Epoch 9/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.5035 - loss: 1.2483
# Epoch 9: val_accuracy improved from 0.65521 to 0.68854, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 394ms/step - accuracy: 0.5035 - loss: 1.2483 - val_accuracy: 0.6885 - val_loss: 0.7895 - learning_rate: 1.0000e-04
# Epoch 10/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.4980 - loss: 1.2283
# Epoch 10: val_accuracy did not improve from 0.68854
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 378ms/step - accuracy: 0.4981 - loss: 1.2281 - val_accuracy: 0.6875 - val_loss: 0.7546 - learning_rate: 1.0000e-04
# Epoch 11/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5079 - loss: 1.2312
# Epoch 11: val_accuracy improved from 0.68854 to 0.71250, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 386ms/step - accuracy: 0.5080 - loss: 1.2310 - val_accuracy: 0.7125 - val_loss: 0.7255 - learning_rate: 1.0000e-04
# Epoch 12/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5211 - loss: 1.1847
# Epoch 12: val_accuracy improved from 0.71250 to 0.72500, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 385ms/step - accuracy: 0.5212 - loss: 1.1844 - val_accuracy: 0.7250 - val_loss: 0.7101 - learning_rate: 1.0000e-04
# Epoch 13/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.5410 - loss: 1.1319
# Epoch 13: val_accuracy improved from 0.72500 to 0.72812, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 374ms/step - accuracy: 0.5411 - loss: 1.1318 - val_accuracy: 0.7281 - val_loss: 0.6827 - learning_rate: 1.0000e-04
# Epoch 14/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.5473 - loss: 1.1044
# Epoch 14: val_accuracy did not improve from 0.72812
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 44s 366ms/step - accuracy: 0.5473 - loss: 1.1044 - val_accuracy: 0.7281 - val_loss: 0.6645 - learning_rate: 1.0000e-04
# Epoch 15/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5357 - loss: 1.1307
# Epoch 15: val_accuracy improved from 0.72812 to 0.74792, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 385ms/step - accuracy: 0.5358 - loss: 1.1305 - val_accuracy: 0.7479 - val_loss: 0.6515 - learning_rate: 1.0000e-04
# Epoch 16/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.5570 - loss: 1.0921
# Epoch 16: val_accuracy improved from 0.74792 to 0.76354, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 389ms/step - accuracy: 0.5570 - loss: 1.0920 - val_accuracy: 0.7635 - val_loss: 0.6310 - learning_rate: 1.0000e-04
# Epoch 17/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.5638 - loss: 1.0494
# Epoch 17: val_accuracy did not improve from 0.76354
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 377ms/step - accuracy: 0.5638 - loss: 1.0495 - val_accuracy: 0.7573 - val_loss: 0.6238 - learning_rate: 1.0000e-04
# Epoch 18/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.5876 - loss: 1.0551
# Epoch 18: val_accuracy improved from 0.76354 to 0.77604, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 389ms/step - accuracy: 0.5876 - loss: 1.0552 - val_accuracy: 0.7760 - val_loss: 0.6046 - learning_rate: 1.0000e-04
# Epoch 19/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.5720 - loss: 1.0259
# Epoch 19: val_accuracy improved from 0.77604 to 0.77708, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 386ms/step - accuracy: 0.5721 - loss: 1.0257 - val_accuracy: 0.7771 - val_loss: 0.5950 - learning_rate: 1.0000e-04
# Epoch 20/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.5891 - loss: 1.0272
# Epoch 20: val_accuracy improved from 0.77708 to 0.78438, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 388ms/step - accuracy: 0.5890 - loss: 1.0272 - val_accuracy: 0.7844 - val_loss: 0.5854 - learning_rate: 1.0000e-04
# Epoch 21/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.6076 - loss: 0.9911
# Epoch 21: val_accuracy did not improve from 0.78438
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 380ms/step - accuracy: 0.6076 - loss: 0.9910 - val_accuracy: 0.7823 - val_loss: 0.5822 - learning_rate: 1.0000e-04
# Epoch 22/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.6047 - loss: 0.9683
# Epoch 22: val_accuracy improved from 0.78438 to 0.79792, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 374ms/step - accuracy: 0.6047 - loss: 0.9684 - val_accuracy: 0.7979 - val_loss: 0.5667 - learning_rate: 1.0000e-04
# Epoch 23/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.6038 - loss: 0.9418
# Epoch 23: val_accuracy did not improve from 0.79792
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 381ms/step - accuracy: 0.6039 - loss: 0.9418 - val_accuracy: 0.7917 - val_loss: 0.5570 - learning_rate: 1.0000e-04
# Epoch 24/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.6108 - loss: 0.9797
# Epoch 24: val_accuracy improved from 0.79792 to 0.80000, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 376ms/step - accuracy: 0.6108 - loss: 0.9796 - val_accuracy: 0.8000 - val_loss: 0.5469 - learning_rate: 1.0000e-04
# Epoch 25/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.6114 - loss: 0.9517
# Epoch 25: val_accuracy improved from 0.80000 to 0.80625, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 382ms/step - accuracy: 0.6114 - loss: 0.9517 - val_accuracy: 0.8062 - val_loss: 0.5279 - learning_rate: 1.0000e-04
# Epoch 26/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.6161 - loss: 0.9344
# Epoch 26: val_accuracy improved from 0.80625 to 0.81563, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 381ms/step - accuracy: 0.6161 - loss: 0.9345 - val_accuracy: 0.8156 - val_loss: 0.5139 - learning_rate: 1.0000e-04
# Epoch 27/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.6229 - loss: 0.9129
# Epoch 27: val_accuracy improved from 0.81563 to 0.81667, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 385ms/step - accuracy: 0.6229 - loss: 0.9128 - val_accuracy: 0.8167 - val_loss: 0.5048 - learning_rate: 1.0000e-04
# Epoch 28/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.6352 - loss: 0.9203
# Epoch 28: val_accuracy did not improve from 0.81667
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 377ms/step - accuracy: 0.6351 - loss: 0.9203 - val_accuracy: 0.8042 - val_loss: 0.4983 - learning_rate: 1.0000e-04
# Epoch 29/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.6448 - loss: 0.8683
# Epoch 29: val_accuracy did not improve from 0.81667
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 388ms/step - accuracy: 0.6448 - loss: 0.8686 - val_accuracy: 0.8104 - val_loss: 0.4993 - learning_rate: 1.0000e-04
# Epoch 30/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.6287 - loss: 0.9132
# Epoch 30: val_accuracy did not improve from 0.81667
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 374ms/step - accuracy: 0.6288 - loss: 0.9131 - val_accuracy: 0.8167 - val_loss: 0.4896 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 27.

# %%
# UNFREEZE LAST 20 LAYERS
for layer in vgg.layers[-4:]:
    layer.trainable = True

# %%
# RECOMPILE

model.compile(
    optimizer=Adam(
        learning_rate=1e-5
    ),

    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history_fine = model.fit(
    train_generator.flow(
        x_train,
        y_train,
        batch_size=BATCH_SIZE
    ),
    steps_per_epoch=x_train.shape[0] // BATCH_SIZE,
    epochs=50,
    validation_data=(x_val, y_val),
    callbacks=[
        checkpoint,
        early_stopping,
        learn_control
    ]
)
# Out:
# Epoch 1/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.6296 - loss: 0.8780
# Epoch 1: val_accuracy improved from 0.81667 to 0.88437, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 58s 412ms/step - accuracy: 0.6298 - loss: 0.8777 - val_accuracy: 0.8844 - val_loss: 0.3812 - learning_rate: 1.0000e-05
# Epoch 2/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.7096 - loss: 0.7133
# Epoch 2: val_accuracy improved from 0.88437 to 0.89896, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 389ms/step - accuracy: 0.7097 - loss: 0.7132 - val_accuracy: 0.8990 - val_loss: 0.2982 - learning_rate: 1.0000e-05
# Epoch 3/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.7671 - loss: 0.5996
# Epoch 3: val_accuracy improved from 0.89896 to 0.91458, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 388ms/step - accuracy: 0.7671 - loss: 0.5996 - val_accuracy: 0.9146 - val_loss: 0.2589 - learning_rate: 1.0000e-05
# Epoch 4/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.7724 - loss: 0.5599
# Epoch 4: val_accuracy improved from 0.91458 to 0.93958, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 395ms/step - accuracy: 0.7725 - loss: 0.5597 - val_accuracy: 0.9396 - val_loss: 0.2004 - learning_rate: 1.0000e-05
# Epoch 5/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.8134 - loss: 0.5017
# Epoch 5: val_accuracy improved from 0.93958 to 0.95833, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 400ms/step - accuracy: 0.8135 - loss: 0.5016 - val_accuracy: 0.9583 - val_loss: 0.1782 - learning_rate: 1.0000e-05
# Epoch 6/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.8277 - loss: 0.4635
# Epoch 6: val_accuracy improved from 0.95833 to 0.96771, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 394ms/step - accuracy: 0.8278 - loss: 0.4633 - val_accuracy: 0.9677 - val_loss: 0.1471 - learning_rate: 1.0000e-05
# Epoch 7/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.8513 - loss: 0.3886
# Epoch 7: val_accuracy improved from 0.96771 to 0.98021, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 391ms/step - accuracy: 0.8514 - loss: 0.3886 - val_accuracy: 0.9802 - val_loss: 0.1275 - learning_rate: 1.0000e-05
# Epoch 8/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8794 - loss: 0.3492
# Epoch 8: val_accuracy improved from 0.98021 to 0.98542, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 387ms/step - accuracy: 0.8794 - loss: 0.3492 - val_accuracy: 0.9854 - val_loss: 0.1123 - learning_rate: 1.0000e-05
# Epoch 9/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8796 - loss: 0.3316
# Epoch 9: val_accuracy did not improve from 0.98542
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 381ms/step - accuracy: 0.8797 - loss: 0.3315 - val_accuracy: 0.9812 - val_loss: 0.1007 - learning_rate: 1.0000e-05
# Epoch 10/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8918 - loss: 0.3087
# Epoch 10: val_accuracy improved from 0.98542 to 0.98958, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 387ms/step - accuracy: 0.8919 - loss: 0.3085 - val_accuracy: 0.9896 - val_loss: 0.0790 - learning_rate: 1.0000e-05
# Epoch 11/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9195 - loss: 0.2523
# Epoch 11: val_accuracy did not improve from 0.98958
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 379ms/step - accuracy: 0.9195 - loss: 0.2523 - val_accuracy: 0.9812 - val_loss: 0.0801 - learning_rate: 1.0000e-05
# Epoch 12/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9301 - loss: 0.2327
# Epoch 12: val_accuracy improved from 0.98958 to 0.99063, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 388ms/step - accuracy: 0.9301 - loss: 0.2327 - val_accuracy: 0.9906 - val_loss: 0.0697 - learning_rate: 1.0000e-05
# Epoch 13/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9321 - loss: 0.2090
# Epoch 13: val_accuracy improved from 0.99063 to 0.99271, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 392ms/step - accuracy: 0.9321 - loss: 0.2091 - val_accuracy: 0.9927 - val_loss: 0.0550 - learning_rate: 1.0000e-05
# Epoch 14/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9398 - loss: 0.1912
# Epoch 14: val_accuracy improved from 0.99271 to 0.99792, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 45s 377ms/step - accuracy: 0.9398 - loss: 0.1913 - val_accuracy: 0.9979 - val_loss: 0.0475 - learning_rate: 1.0000e-05
# Epoch 15/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9461 - loss: 0.1840
# Epoch 15: val_accuracy did not improve from 0.99792
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 396ms/step - accuracy: 0.9461 - loss: 0.1840 - val_accuracy: 0.9979 - val_loss: 0.0376 - learning_rate: 1.0000e-05
# Epoch 16/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9467 - loss: 0.1842
# Epoch 16: val_accuracy improved from 0.99792 to 1.00000, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 389ms/step - accuracy: 0.9468 - loss: 0.1841 - val_accuracy: 1.0000 - val_loss: 0.0331 - learning_rate: 1.0000e-05
# Epoch 17/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9549 - loss: 0.1635
# Epoch 17: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 381ms/step - accuracy: 0.9549 - loss: 0.1634 - val_accuracy: 1.0000 - val_loss: 0.0271 - learning_rate: 1.0000e-05
# Epoch 18/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9621 - loss: 0.1449
# Epoch 18: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 388ms/step - accuracy: 0.9621 - loss: 0.1449 - val_accuracy: 1.0000 - val_loss: 0.0249 - learning_rate: 1.0000e-05
# Epoch 19/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9637 - loss: 0.1344
# Epoch 19: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 391ms/step - accuracy: 0.9637 - loss: 0.1344 - val_accuracy: 1.0000 - val_loss: 0.0220 - learning_rate: 1.0000e-05
# Epoch 20/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9663 - loss: 0.1244
# Epoch 20: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 388ms/step - accuracy: 0.9663 - loss: 0.1244 - val_accuracy: 1.0000 - val_loss: 0.0177 - learning_rate: 1.0000e-05
# Epoch 21/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9726 - loss: 0.1118
# Epoch 21: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 384ms/step - accuracy: 0.9726 - loss: 0.1118 - val_accuracy: 1.0000 - val_loss: 0.0196 - learning_rate: 1.0000e-05
# Epoch 22/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9686 - loss: 0.1137
# Epoch 22: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 387ms/step - accuracy: 0.9686 - loss: 0.1137 - val_accuracy: 1.0000 - val_loss: 0.0168 - learning_rate: 1.0000e-05
# Epoch 23/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9766 - loss: 0.0920
# Epoch 23: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 387ms/step - accuracy: 0.9766 - loss: 0.0920 - val_accuracy: 1.0000 - val_loss: 0.0141 - learning_rate: 1.0000e-05
# Epoch 24/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9791 - loss: 0.0901
# Epoch 24: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 384ms/step - accuracy: 0.9791 - loss: 0.0900 - val_accuracy: 1.0000 - val_loss: 0.0113 - learning_rate: 1.0000e-05
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 16.

# %%
y_pred = model.predict(x_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))

cm_plot_label =['Benign (BI-RADS 2)', 'Benign (BI-RADS 3)', 'Malign (BI-RADS 4)', 'Malign (BI-RADS 5)']
plot_confusion_matrix(cm, cm_plot_label, title ='Multiclass Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[14  0  0  0]
#  [ 0 38  0  1]
#  [ 0  1 43  1]
#  [ 1  1  0 33]]

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

t = f.suptitle('Multiscale Transfer Learning Model', fontsize=12)

f.subplots_adjust(top=0.85, wspace=0.3)

# Dynamic epoch count
epoch_list = range(1, len(history.history['accuracy']) + 1)

# Accuracy Plot
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')

ax1.grid()
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
ax1.legend(loc="best")

# Loss Plot
ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')

ax2.grid()
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
ax2.legend(loc="best")

plt.show()

# %%
print("y_test:", y_test.shape)
print("y_pred:", y_pred.shape)
# Out:
# y_test: (133, 4)
# y_pred: (133, 4)

# %%
import numpy as np
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    matthews_corrcoef,
    mean_absolute_error,
    mean_squared_error,
    cohen_kappa_score
)

# Predictions
pred = model.predict(x_test)
y_pred = np.argmax(pred, axis=1)
y_test = np.argmax(y_test, axis=1)

# Target labels
target_names = [
    'Benign (BI-RADS 2)',
    'Benign (BI-RADS 3)',
    'Malign (BI-RADS 4)',
    'Malign (BI-RADS 5)'
]

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=target_names))

# Confusion Matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# Additional Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
mcc = matthews_corrcoef(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
kappa = cohen_kappa_score(y_test, y_pred)

# Print all metrics
print("\nAdditional Evaluation Metrics:")
print(f"Accuracy       : {accuracy:.4f}")
print(f"Precision      : {precision:.4f}")
print(f"Recall         : {recall:.4f}")
print(f"F1-score       : {f1:.4f}")
print(f"MCC            : {mcc:.4f}")
print(f"MAE            : {mae:.4f}")
print(f"MSE            : {mse:.4f}")
print(f"Cohen's Kappa  : {kappa:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step
# Classification Report:
#                     precision    recall  f1-score   support
#
# Benign (BI-RADS 2)       0.93      1.00      0.97        14
# Benign (BI-RADS 3)       0.95      0.97      0.96        39
# Malign (BI-RADS 4)       1.00      0.96      0.98        45
# Malign (BI-RADS 5)       0.94      0.94      0.94        35
#
#           accuracy                           0.96       133
#          macro avg       0.96      0.97      0.96       133
#       weighted avg       0.96      0.96      0.96       133
#
# Confusion Matrix:
# [[14  0  0  0]
#  [ 0 38  0  1]
#  [ 0  1 43  1]
#  [ 1  1  0 33]]
#
# Additional Evaluation Metrics:
# Accuracy       : 0.9624
# Precision      : 0.9633
# Recall         : 0.9624
# F1-score       : 0.9625
# MCC            : 0.9481
# MAE            : 0.0677
# MSE            : 0.1429
# Cohen's Kappa  : 0.9479
