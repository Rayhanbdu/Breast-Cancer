# %%
import json
import math
import os
import gc
import itertools
from functools import partial
from collections import Counter

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

from PIL import Image
from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras import layers, backend as K
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Dropout, Flatten, Dense, GlobalAveragePooling2D, Average,
    Input, Concatenate, GlobalMaxPooling2D, BatchNormalization
)
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input

from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
from sklearn import metrics

# %matplotlib inline
# Out:
# 2026-05-16 09:44:00.463081: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778924640.638245      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778924640.689310      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778924641.100023      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778924641.100072      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778924641.100076      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778924641.100080      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf

# Disable XLA
tf.config.optimizer.set_jit(False)

# %%
def Dataset_loader_recursive(DIR, RESIZE):
    IMG = []
    
    for root, _, files in os.walk(DIR):
        for file in files:
            PATH = os.path.join(root, file)
            _, ftype = os.path.splitext(PATH)
            
            if ftype.lower() in [".jpg", ".jpeg", ".png"]:
                try:
                    img = np.asarray(Image.open(PATH).convert("RGB"))
                    img = cv2.resize(img, (RESIZE, RESIZE))
                    IMG.append(img)
                except:
                    continue
    
    return np.array(IMG)
DIR = "/kaggle/input/datasets/tueoban/aisslab-breast-cancer-sub-datasets/AISSLab Sub-datasets/Augmented Sub-datasets/AISSLab-v5/"

benign_bi_rads_2 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 2"), RESIZE=224)
benign_bi_rads_3 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 3"), RESIZE=224)

malignant_bi_rads_4 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 4"), RESIZE=224)
malignant_bi_rads_5 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 5"), RESIZE=224)

#normal = Dataset_loader_recursive(os.path.join(DIR, "Normal/JPG/"), RESIZE=224)

# %%
print("Total images loaded:", len(benign_bi_rads_2))
print("Shape:", benign_bi_rads_2.shape)

print("Total images loaded:", len(benign_bi_rads_3))
print("Shape:", benign_bi_rads_3.shape)

print("Total images loaded:", len(malignant_bi_rads_4))
print("Shape:", malignant_bi_rads_4.shape)

print("Total images loaded:", len(malignant_bi_rads_5))
print("Shape:", malignant_bi_rads_5.shape)
# Out:
# Total images loaded: 72
# Shape: (72, 224, 224, 3)
# Total images loaded: 192
# Shape: (192, 224, 224, 3)
# Total images loaded: 224
# Shape: (224, 224, 224, 3)
# Total images loaded: 176
# Shape: (176, 224, 224, 3)

# %%
#normal_label = np.full(len(normal),0)
benign_bi_rads_2_label = np.full(len(benign_bi_rads_2), 0)
benign_bi_rads_3_label = np.full(len(benign_bi_rads_3),1)
malignant_bi_rads_4_label = np.full(len(malignant_bi_rads_4),2)
malignant_bi_rads_5_label = np.full(len(malignant_bi_rads_5),3)

# %%
X = np.concatenate((benign_bi_rads_2, benign_bi_rads_3, malignant_bi_rads_4, malignant_bi_rads_5), axis = 0)
Y = np.concatenate((benign_bi_rads_2_label, benign_bi_rads_3_label, malignant_bi_rads_4_label, malignant_bi_rads_5_label), axis = 0)

# Shuffle train data
s = np.arange(X.shape[0])
np.random.shuffle(s)
X = X[s]
Y = Y[s]

# DENSENET PREPROCESSING
X = preprocess_input(
    X.astype("float32")
)
x_train, x_test, y_train, y_test = train_test_split(
    X, Y, 
    test_size=0.2, 
    random_state=11,
    stratify=Y
)

# %%
from imblearn.over_sampling import RandomOverSampler
from tensorflow.keras.utils import to_categorical
from collections import Counter
import numpy as np

# -----------------------------
# Convert one-hot -> labels if needed
# -----------------------------
if len(y_train.shape) > 1:
    y_train_labels = np.argmax(y_train, axis=1)
else:
    y_train_labels = y_train

# -----------------------------
# Check original distribution
# -----------------------------
print("Original class distribution:")
print(Counter(y_train_labels))

# -----------------------------
# Flatten image data temporarily
# -----------------------------
nsamples, h, w, c = x_train.shape

x_train_flat = x_train.reshape(
    (nsamples, h * w * c)
)

target = 1200
# -----------------------------
# Target: 100 samples per class
# -----------------------------
sampling_strategy = {
    0: target,
    1: target,
    2: target,
    3: target
}

# -----------------------------
# Apply Oversampling
# -----------------------------
ros = RandomOverSampler(
    sampling_strategy=sampling_strategy,
    random_state=42
)

x_train, y_train = ros.fit_resample(
    x_train_flat,
    y_train_labels
)

# -----------------------------
# Restore image shape
# -----------------------------
x_train = x_train.reshape(
    (-1, h, w, c)
)

# -----------------------------
# One-hot Encode Labels
# -----------------------------
y_train = to_categorical(
    y_train,
    num_classes=4
)

# -----------------------------
# Validation labels
# -----------------------------
if len(y_test.shape) == 1:
    y_test = to_categorical(y_test, num_classes=4)

# -----------------------------
# Final Distribution
# -----------------------------
print("\nBalanced class distribution:")
print(Counter(np.argmax(y_train, axis=1)))
# Out:
# Original class distribution:
# Counter({np.int64(2): 179, np.int64(1): 153, np.int64(3): 141, np.int64(0): 58})
#
# Balanced class distribution:
# Counter({np.int64(3): 1200, np.int64(0): 1200, np.int64(1): 1200, np.int64(2): 1200})

# %%
x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, 
    test_size=0.2, 
    random_state=11,
    stratify=np.argmax(y_train, axis=1)
)
print("\nFinal Shapes:")
print("x_train:", x_train.shape)
print("y_train:", y_train.shape)
print("x_val:", x_val.shape)
print("y_val:", y_val.shape)
print("x_test:", x_test.shape)
print("y_test:", y_test.shape)
# Out:
# Final Shapes:
# x_train: (3840, 224, 224, 3)
# y_train: (3840, 4)
# x_val: (960, 224, 224, 3)
# y_val: (960, 4)
# x_test: (133, 224, 224, 3)
# y_test: (133, 4)

# %%
BATCH_SIZE = 32

# Using original generator
train_generator = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=False
)

# %%
IMAGE_SIZE = 224

input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)
inputs = Input(shape=input_shape)

# PRETRAINED VGG19
vgg = VGG19(
    weights='imagenet',
    include_top=False,
    input_tensor=inputs
)
# Out:
# I0000 00:00:1778924720.020055      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1778924720.025836      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# FREEZE
for layer in vgg.layers:
    layer.trainable = False

# %%
# CLASSIFIER HEAD
x = vgg.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(256,activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.4)(x)
outputs = Dense(4,activation='softmax')(x)

# FINAL MODEL
model = Model(inputs,outputs)

# %%
# COMPILE
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,159,812 (76.90 MB)
#  Trainable params: 133,892 (523.02 KB)
#  Non-trainable params: 20,025,920 (76.39 MB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

filepath = "/kaggle/working/best_AISSlab.keras"

checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',   # also fix this (see below 👇)
    verbose=1,
    save_best_only=True,
    mode='max'
)

# Early stopping
early_stopping = EarlyStopping(
    monitor='val_accuracy',  
    patience=8,             
    verbose=1,
    mode='max',
    restore_best_weights=True
)

# LR 
learn_control = ReduceLROnPlateau(
    monitor='val_loss',
    patience=3,
    factor=0.3,
    min_lr=1e-6,
    verbose=1
)

# %%
history = model.fit(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] // BATCH_SIZE,
    epochs=30,
    validation_data=(x_val, y_val),
    callbacks=[checkpoint, early_stopping, learn_control]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778924724.940761      73 service.cc:152] XLA service 0x7c31c4006780 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778924724.940809      73 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1778924724.940815      73 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1778924725.586267      73 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   1/120 ━━━━━━━━━━━━━━━━━━━━ 32:09 16s/step - accuracy: 0.2500 - loss: 2.3382
# I0000 00:00:1778924738.772158      73 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.3093 - loss: 2.0546
# Epoch 1: val_accuracy improved from -inf to 0.37187, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 65s 412ms/step - accuracy: 0.3093 - loss: 2.0540 - val_accuracy: 0.3719 - val_loss: 1.4357 - learning_rate: 1.0000e-04
# Epoch 2/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.3507 - loss: 1.8476
# Epoch 2: val_accuracy improved from 0.37187 to 0.52396, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 386ms/step - accuracy: 0.3508 - loss: 1.8473 - val_accuracy: 0.5240 - val_loss: 1.1784 - learning_rate: 1.0000e-04
# Epoch 3/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.3883 - loss: 1.6523
# Epoch 3: val_accuracy improved from 0.52396 to 0.56458, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 390ms/step - accuracy: 0.3883 - loss: 1.6520 - val_accuracy: 0.5646 - val_loss: 1.0832 - learning_rate: 1.0000e-04
# Epoch 4/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4206 - loss: 1.5887
# Epoch 4: val_accuracy improved from 0.56458 to 0.60208, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 389ms/step - accuracy: 0.4206 - loss: 1.5885 - val_accuracy: 0.6021 - val_loss: 0.9984 - learning_rate: 1.0000e-04
# Epoch 5/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.4461 - loss: 1.4900
# Epoch 5: val_accuracy improved from 0.60208 to 0.60625, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 391ms/step - accuracy: 0.4461 - loss: 1.4899 - val_accuracy: 0.6062 - val_loss: 0.9393 - learning_rate: 1.0000e-04
# Epoch 6/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.4431 - loss: 1.4493
# Epoch 6: val_accuracy improved from 0.60625 to 0.63021, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 391ms/step - accuracy: 0.4433 - loss: 1.4490 - val_accuracy: 0.6302 - val_loss: 0.8910 - learning_rate: 1.0000e-04
# Epoch 7/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.4899 - loss: 1.3187
# Epoch 7: val_accuracy improved from 0.63021 to 0.63542, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 400ms/step - accuracy: 0.4898 - loss: 1.3189 - val_accuracy: 0.6354 - val_loss: 0.8621 - learning_rate: 1.0000e-04
# Epoch 8/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.5040 - loss: 1.2796
# Epoch 8: val_accuracy improved from 0.63542 to 0.64271, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 399ms/step - accuracy: 0.5038 - loss: 1.2798 - val_accuracy: 0.6427 - val_loss: 0.8225 - learning_rate: 1.0000e-04
# Epoch 9/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.5044 - loss: 1.2445
# Epoch 9: val_accuracy improved from 0.64271 to 0.66875, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 395ms/step - accuracy: 0.5043 - loss: 1.2448 - val_accuracy: 0.6687 - val_loss: 0.7776 - learning_rate: 1.0000e-04
# Epoch 10/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.5295 - loss: 1.1983
# Epoch 10: val_accuracy improved from 0.66875 to 0.69375, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 387ms/step - accuracy: 0.5295 - loss: 1.1983 - val_accuracy: 0.6938 - val_loss: 0.7655 - learning_rate: 1.0000e-04
# Epoch 11/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.5078 - loss: 1.2457
# Epoch 11: val_accuracy improved from 0.69375 to 0.70312, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 394ms/step - accuracy: 0.5079 - loss: 1.2454 - val_accuracy: 0.7031 - val_loss: 0.7337 - learning_rate: 1.0000e-04
# Epoch 12/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.5273 - loss: 1.1775
# Epoch 12: val_accuracy improved from 0.70312 to 0.72396, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 391ms/step - accuracy: 0.5273 - loss: 1.1775 - val_accuracy: 0.7240 - val_loss: 0.7160 - learning_rate: 1.0000e-04
# Epoch 13/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.5324 - loss: 1.1600
# Epoch 13: val_accuracy improved from 0.72396 to 0.72500, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 396ms/step - accuracy: 0.5324 - loss: 1.1601 - val_accuracy: 0.7250 - val_loss: 0.6898 - learning_rate: 1.0000e-04
# Epoch 14/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.5494 - loss: 1.1265
# Epoch 14: val_accuracy improved from 0.72500 to 0.73958, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 391ms/step - accuracy: 0.5493 - loss: 1.1266 - val_accuracy: 0.7396 - val_loss: 0.6709 - learning_rate: 1.0000e-04
# Epoch 15/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.5462 - loss: 1.1171
# Epoch 15: val_accuracy improved from 0.73958 to 0.74896, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 393ms/step - accuracy: 0.5462 - loss: 1.1171 - val_accuracy: 0.7490 - val_loss: 0.6534 - learning_rate: 1.0000e-04
# Epoch 16/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.5445 - loss: 1.1250
# Epoch 16: val_accuracy improved from 0.74896 to 0.75729, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 394ms/step - accuracy: 0.5446 - loss: 1.1247 - val_accuracy: 0.7573 - val_loss: 0.6325 - learning_rate: 1.0000e-04
# Epoch 17/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.5543 - loss: 1.0708
# Epoch 17: val_accuracy did not improve from 0.75729
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 397ms/step - accuracy: 0.5544 - loss: 1.0708 - val_accuracy: 0.7552 - val_loss: 0.6204 - learning_rate: 1.0000e-04
# Epoch 18/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.5815 - loss: 1.0580
# Epoch 18: val_accuracy improved from 0.75729 to 0.78854, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 391ms/step - accuracy: 0.5814 - loss: 1.0579 - val_accuracy: 0.7885 - val_loss: 0.6122 - learning_rate: 1.0000e-04
# Epoch 19/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.5838 - loss: 1.0435
# Epoch 19: val_accuracy improved from 0.78854 to 0.79062, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 394ms/step - accuracy: 0.5837 - loss: 1.0435 - val_accuracy: 0.7906 - val_loss: 0.5958 - learning_rate: 1.0000e-04
# Epoch 20/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.5706 - loss: 1.0475
# Epoch 20: val_accuracy did not improve from 0.79062
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 389ms/step - accuracy: 0.5706 - loss: 1.0472 - val_accuracy: 0.7875 - val_loss: 0.5903 - learning_rate: 1.0000e-04
# Epoch 21/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.5824 - loss: 1.0166
# Epoch 21: val_accuracy did not improve from 0.79062
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 401ms/step - accuracy: 0.5825 - loss: 1.0165 - val_accuracy: 0.7792 - val_loss: 0.5777 - learning_rate: 1.0000e-04
# Epoch 22/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.5899 - loss: 1.0152
# Epoch 22: val_accuracy improved from 0.79062 to 0.79583, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 400ms/step - accuracy: 0.5898 - loss: 1.0151 - val_accuracy: 0.7958 - val_loss: 0.5716 - learning_rate: 1.0000e-04
# Epoch 23/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5826 - loss: 1.0447
# Epoch 23: val_accuracy improved from 0.79583 to 0.80625, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 402ms/step - accuracy: 0.5826 - loss: 1.0446 - val_accuracy: 0.8062 - val_loss: 0.5562 - learning_rate: 1.0000e-04
# Epoch 24/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5727 - loss: 1.0358
# Epoch 24: val_accuracy improved from 0.80625 to 0.81354, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 402ms/step - accuracy: 0.5728 - loss: 1.0356 - val_accuracy: 0.8135 - val_loss: 0.5460 - learning_rate: 1.0000e-04
# Epoch 25/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5872 - loss: 1.0080
# Epoch 25: val_accuracy improved from 0.81354 to 0.81979, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 403ms/step - accuracy: 0.5873 - loss: 1.0077 - val_accuracy: 0.8198 - val_loss: 0.5467 - learning_rate: 1.0000e-04
# Epoch 26/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.6146 - loss: 0.9380
# Epoch 26: val_accuracy did not improve from 0.81979
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 400ms/step - accuracy: 0.6145 - loss: 0.9382 - val_accuracy: 0.8042 - val_loss: 0.5436 - learning_rate: 1.0000e-04
# Epoch 27/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.6063 - loss: 0.9696
# Epoch 27: val_accuracy did not improve from 0.81979
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 395ms/step - accuracy: 0.6063 - loss: 0.9694 - val_accuracy: 0.8156 - val_loss: 0.5321 - learning_rate: 1.0000e-04
# Epoch 28/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.6263 - loss: 0.9227
# Epoch 28: val_accuracy did not improve from 0.81979
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 390ms/step - accuracy: 0.6262 - loss: 0.9227 - val_accuracy: 0.8198 - val_loss: 0.5278 - learning_rate: 1.0000e-04
# Epoch 29/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.6360 - loss: 0.9047
# Epoch 29: val_accuracy did not improve from 0.81979
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 389ms/step - accuracy: 0.6360 - loss: 0.9047 - val_accuracy: 0.8188 - val_loss: 0.5189 - learning_rate: 1.0000e-04
# Epoch 30/30
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.6166 - loss: 0.9355
# Epoch 30: val_accuracy improved from 0.81979 to 0.82604, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 46s 384ms/step - accuracy: 0.6167 - loss: 0.9354 - val_accuracy: 0.8260 - val_loss: 0.5165 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 30.

# %%
# UNFREEZE LAST 20 LAYERS
for layer in vgg.layers[-4:]:
    layer.trainable = True

# %%
# RECOMPILE

model.compile(
    optimizer=Adam(
        learning_rate=1e-5
    ),

    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history_fine = model.fit(
    train_generator.flow(
        x_train,
        y_train,
        batch_size=BATCH_SIZE
    ),
    steps_per_epoch=x_train.shape[0] // BATCH_SIZE,
    epochs=50,
    validation_data=(x_val, y_val),
    callbacks=[
        checkpoint,
        early_stopping,
        learn_control
    ]
)
# Out:
# Epoch 1/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.6386 - loss: 0.8920
# Epoch 1: val_accuracy improved from 0.82604 to 0.89375, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 58s 417ms/step - accuracy: 0.6388 - loss: 0.8916 - val_accuracy: 0.8938 - val_loss: 0.3746 - learning_rate: 1.0000e-05
# Epoch 2/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6975 - loss: 0.7569
# Epoch 2: val_accuracy improved from 0.89375 to 0.92604, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 49s 405ms/step - accuracy: 0.6976 - loss: 0.7566 - val_accuracy: 0.9260 - val_loss: 0.3082 - learning_rate: 1.0000e-05
# Epoch 3/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.7308 - loss: 0.6481
# Epoch 3: val_accuracy improved from 0.92604 to 0.95312, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 49s 409ms/step - accuracy: 0.7310 - loss: 0.6480 - val_accuracy: 0.9531 - val_loss: 0.2701 - learning_rate: 1.0000e-05
# Epoch 4/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.7752 - loss: 0.5792
# Epoch 4: val_accuracy improved from 0.95312 to 0.95729, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 49s 406ms/step - accuracy: 0.7752 - loss: 0.5791 - val_accuracy: 0.9573 - val_loss: 0.2206 - learning_rate: 1.0000e-05
# Epoch 5/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8034 - loss: 0.5158
# Epoch 5: val_accuracy improved from 0.95729 to 0.96979, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 401ms/step - accuracy: 0.8034 - loss: 0.5157 - val_accuracy: 0.9698 - val_loss: 0.1937 - learning_rate: 1.0000e-05
# Epoch 6/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.8189 - loss: 0.4535
# Epoch 6: val_accuracy improved from 0.96979 to 0.97083, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 49s 411ms/step - accuracy: 0.8189 - loss: 0.4535 - val_accuracy: 0.9708 - val_loss: 0.1690 - learning_rate: 1.0000e-05
# Epoch 7/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.8250 - loss: 0.4488
# Epoch 7: val_accuracy improved from 0.97083 to 0.98958, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 49s 406ms/step - accuracy: 0.8251 - loss: 0.4486 - val_accuracy: 0.9896 - val_loss: 0.1312 - learning_rate: 1.0000e-05
# Epoch 8/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.8419 - loss: 0.4047
# Epoch 8: val_accuracy improved from 0.98958 to 0.99063, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 399ms/step - accuracy: 0.8420 - loss: 0.4045 - val_accuracy: 0.9906 - val_loss: 0.1113 - learning_rate: 1.0000e-05
# Epoch 9/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.8758 - loss: 0.3585
# Epoch 9: val_accuracy did not improve from 0.99063
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 395ms/step - accuracy: 0.8759 - loss: 0.3584 - val_accuracy: 0.9854 - val_loss: 0.1097 - learning_rate: 1.0000e-05
# Epoch 10/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.8688 - loss: 0.3664
# Epoch 10: val_accuracy improved from 0.99063 to 0.99792, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 49s 404ms/step - accuracy: 0.8688 - loss: 0.3662 - val_accuracy: 0.9979 - val_loss: 0.0820 - learning_rate: 1.0000e-05
# Epoch 11/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8953 - loss: 0.3091
# Epoch 11: val_accuracy improved from 0.99792 to 1.00000, saving model to /kaggle/working/best_AISSlab.keras
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 402ms/step - accuracy: 0.8954 - loss: 0.3089 - val_accuracy: 1.0000 - val_loss: 0.0702 - learning_rate: 1.0000e-05
# Epoch 12/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9057 - loss: 0.2823
# Epoch 12: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 393ms/step - accuracy: 0.9056 - loss: 0.2823 - val_accuracy: 0.9990 - val_loss: 0.0637 - learning_rate: 1.0000e-05
# Epoch 13/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9208 - loss: 0.2560
# Epoch 13: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 49s 403ms/step - accuracy: 0.9208 - loss: 0.2559 - val_accuracy: 0.9990 - val_loss: 0.0471 - learning_rate: 1.0000e-05
# Epoch 14/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.9308 - loss: 0.2325
# Epoch 14: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 402ms/step - accuracy: 0.9309 - loss: 0.2325 - val_accuracy: 1.0000 - val_loss: 0.0498 - learning_rate: 1.0000e-05
# Epoch 15/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9485 - loss: 0.2060
# Epoch 15: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 397ms/step - accuracy: 0.9484 - loss: 0.2060 - val_accuracy: 1.0000 - val_loss: 0.0354 - learning_rate: 1.0000e-05
# Epoch 16/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9416 - loss: 0.1903
# Epoch 16: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 47s 392ms/step - accuracy: 0.9417 - loss: 0.1902 - val_accuracy: 0.9979 - val_loss: 0.0413 - learning_rate: 1.0000e-05
# Epoch 17/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9441 - loss: 0.1778
# Epoch 17: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 401ms/step - accuracy: 0.9442 - loss: 0.1778 - val_accuracy: 1.0000 - val_loss: 0.0282 - learning_rate: 1.0000e-05
# Epoch 18/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9471 - loss: 0.1714
# Epoch 18: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 48s 398ms/step - accuracy: 0.9472 - loss: 0.1713 - val_accuracy: 1.0000 - val_loss: 0.0300 - learning_rate: 1.0000e-05
# Epoch 19/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.9582 - loss: 0.1563
# Epoch 19: val_accuracy did not improve from 1.00000
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 49s 406ms/step - accuracy: 0.9582 - loss: 0.1563 - val_accuracy: 1.0000 - val_loss: 0.0270 - learning_rate: 1.0000e-05
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 11.

# %%
y_pred = model.predict(x_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))

cm_plot_label =['Benign (BI-RADS 2)', 'Benign (BI-RADS 3)', 'Malign (BI-RADS 4)', 'Malign (BI-RADS 5)']
plot_confusion_matrix(cm, cm_plot_label, title ='Multiclass Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[14  0  0  0]
#  [ 0 35  3  1]
#  [ 2  0 43  0]
#  [ 0  0  0 35]]

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

t = f.suptitle('Multiscale Transfer Learning Model', fontsize=12)

f.subplots_adjust(top=0.85, wspace=0.3)

# Dynamic epoch count
epoch_list = range(1, len(history.history['accuracy']) + 1)

# Accuracy Plot
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')

ax1.grid()
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
ax1.legend(loc="best")

# Loss Plot
ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')

ax2.grid()
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
ax2.legend(loc="best")

plt.show()

# %%
print("y_test:", y_test.shape)
print("y_pred:", y_pred.shape)
# Out:
# y_test: (133, 4)
# y_pred: (133, 4)

# %%
import numpy as np
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    matthews_corrcoef,
    mean_absolute_error,
    mean_squared_error,
    cohen_kappa_score
)

# Predictions
pred = model.predict(x_test)
y_pred = np.argmax(pred, axis=1)
y_test = np.argmax(y_test, axis=1)

# Target labels
target_names = [
    'Benign (BI-RADS 2)',
    'Benign (BI-RADS 3)',
    'Malign (BI-RADS 4)',
    'Malign (BI-RADS 5)'
]

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=target_names))

# Confusion Matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# Additional Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
mcc = matthews_corrcoef(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
kappa = cohen_kappa_score(y_test, y_pred)

# Print all metrics
print("\nAdditional Evaluation Metrics:")
print(f"Accuracy       : {accuracy:.4f}")
print(f"Precision      : {precision:.4f}")
print(f"Recall         : {recall:.4f}")
print(f"F1-score       : {f1:.4f}")
print(f"MCC            : {mcc:.4f}")
print(f"MAE            : {mae:.4f}")
print(f"MSE            : {mse:.4f}")
print(f"Cohen's Kappa  : {kappa:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# Classification Report:
#                     precision    recall  f1-score   support
#
# Benign (BI-RADS 2)       0.88      1.00      0.93        14
# Benign (BI-RADS 3)       1.00      0.90      0.95        39
# Malign (BI-RADS 4)       0.93      0.96      0.95        45
# Malign (BI-RADS 5)       0.97      1.00      0.99        35
#
#           accuracy                           0.95       133
#          macro avg       0.95      0.96      0.95       133
#       weighted avg       0.96      0.95      0.95       133
#
# Confusion Matrix:
# [[14  0  0  0]
#  [ 0 35  3  1]
#  [ 2  0 43  0]
#  [ 0  0  0 35]]
#
# Additional Evaluation Metrics:
# Accuracy       : 0.9549
# Precision      : 0.9575
# Recall         : 0.9549
# F1-score       : 0.9548
# MCC            : 0.9383
# MAE            : 0.0677
# MSE            : 0.1128
# Cohen's Kappa  : 0.9375
